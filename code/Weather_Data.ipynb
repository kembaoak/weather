# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (91 kB)
# ...
#   Using cached numpy-2.3.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.3.2-cp313-cp313-macosx_11_0_arm64.whl (10.7 MB)
# Using cached numpy-2.3.3-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]2m3/4 [pandas]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 11.5 MB/s eta 0:00:00a 0:00:01
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 13.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn as sns
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Importing all libraries we would need to perform our work

# %%
#importing all important libraries and functions
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

sns.set_style("whitegrid")

# %%
#loading the data for seattle

df_seattle = pd.read_csv('https://raw.githubusercontent.com/kembaoak/weather/refs/heads/main/data/seattle_rain.csv')

# %% [markdown]
# For line 21 and 22, in order to import our dataset. We use a function .read_csv which is a panda function. This allows us to import data from github. For line 21, we import data for michigan and import data for seattle in line 22.

# %%
#loading in data for Michigan
df_michigan = pd.read_csv('https://raw.githubusercontent.com/kembaoak/weather/refs/heads/main/data/michigan_rain.csv')

# %% [markdown]
# Output: dataset is imported from github and assigned to df_seattle and df_michigan respectively.

# %% [markdown]
# To view data in our table, we use our dataframe with the .head() function

# %%
#viewing contents of the tables for seattle data using .heads()
df_seattle.head()
# Out:
#        STATION                    NAME    DATE  DAPR  MDPR  PRCP  SNOW  SNWD  \
# 0  US1WAKG0225  SEATTLE 2.1 ESE, WA US  1/1/18   NaN   NaN  0.00   NaN   NaN
# 1  US1WAKG0225  SEATTLE 2.1 ESE, WA US  1/2/18   NaN   NaN  0.00   NaN   NaN
# 2  US1WAKG0225  SEATTLE 2.1 ESE, WA US  1/3/18   NaN   NaN  0.00   NaN   NaN
# 3  US1WAKG0225  SEATTLE 2.1 ESE, WA US  1/4/18   NaN   NaN  0.00   NaN   NaN
# 4  US1WAKG0225  SEATTLE 2.1 ESE, WA US  1/5/18   NaN   NaN  0.25   NaN   NaN
#
#    WESD  WESF
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# 3   NaN   NaN
# 4   NaN   NaN

# %% [markdown]
# output shows first 5 records of our data set including the column titles. This basically allows us to view our table

# %% [markdown]
# Dispalys the first 5 data for Michigan dataset

# %%
#viewing contents of the tables for Michigan data using .heads() function
df_michigan.head()
# Out:
#        STATION                        NAME   LATITUDE  LONGITUDE  ELEVATION  \
# 0  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
# 1  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
# 2  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
# 3  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
# 4  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
#
#          DATE  DAPR DAPR_ATTRIBUTES  MDPR MDPR_ATTRIBUTES  PRCP  \
# 0  2018-01-01   NaN             NaN   NaN             NaN  0.00
# 1  2018-01-02   NaN             NaN   NaN             NaN  0.00
# 2  2018-01-03   NaN             NaN   NaN             NaN  0.00
# 3  2018-01-04   NaN             NaN   NaN             NaN  0.02
# 4  2018-01-05   NaN             NaN   NaN             NaN  0.00
#
#   PRCP_ATTRIBUTES  SNOW SNOW_ATTRIBUTES  SNWD SNWD_ATTRIBUTES  WESD  \
# ...

# %% [markdown]
# Displays first 10 records in data set.

# %%
#to view 10 rows of the data set
df_seattle.head(10)
# Out:
#        STATION                    NAME     DATE  DAPR  MDPR  PRCP  SNOW  SNWD  \
# 0  US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/1/18   NaN   NaN  0.00   NaN   NaN
# 1  US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/2/18   NaN   NaN  0.00   NaN   NaN
# 2  US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/3/18   NaN   NaN  0.00   NaN   NaN
# 3  US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/4/18   NaN   NaN  0.00   NaN   NaN
# 4  US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/5/18   NaN   NaN  0.25   NaN   NaN
# 5  US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/6/18   NaN   NaN  0.57   NaN   NaN
# 6  US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/7/18   NaN   NaN  0.23   NaN   NaN
# 7  US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/8/18   NaN   NaN  0.41   NaN   NaN
# 8  US1WAKG0225  SEATTLE 2.1 ESE, WA US  3/12/18   NaN   NaN  0.00   NaN   NaN
# 9  US1WAKG0225  SEATTLE 2.1 ESE, WA US  3/13/18   NaN   NaN  0.00   NaN   NaN
#
#    WESD  WESF
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# 3   NaN   NaN
# 4   NaN   NaN
# 5   NaN   NaN
# ...

# %% [markdown]
# output shows first 10 recoirds in our dataset.

# %%
#To view 10 rows of the data set of Michigan
df_michigan.head(10)
# Out:
#        STATION                        NAME   LATITUDE  LONGITUDE  ELEVATION  \
# 0  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
# 1  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
# 2  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
# 3  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
# 4  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
# 5  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
# 6  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
# 7  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
# 8  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
# 9  US1MIMR0016  OTTAWA LAKE 1.4 SSW, MI US  41.782787 -83.738953      209.7
#
#          DATE  DAPR DAPR_ATTRIBUTES  MDPR MDPR_ATTRIBUTES  PRCP  \
# 0  2018-01-01   NaN             NaN   NaN             NaN  0.00
# ...

# %% [markdown]
# For 26 and 27, .columns is an attribute of a Panda's dataframe. It returns an index object containing the names of all the columns in df_seattle.

# %%
df_seattle.columns
# Out:
# Index(['STATION', 'NAME', 'DATE', 'DAPR', 'MDPR', 'PRCP', 'SNOW', 'SNWD',
#        'WESD', 'WESF'],
#       dtype='object')

# %% [markdown]
# outputs all columns for the seattle dataset.

# %%
df_michigan.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'DAPR',
#        'DAPR_ATTRIBUTES', 'MDPR', 'MDPR_ATTRIBUTES', 'PRCP', 'PRCP_ATTRIBUTES',
#        'SNOW', 'SNOW_ATTRIBUTES', 'SNWD', 'SNWD_ATTRIBUTES', 'WESD',
#        'WESD_ATTRIBUTES', 'WESF', 'WESF_ATTRIBUTES'],
#       dtype='object')

# %% [markdown]
# output shows all columns on the michigan dataset.

# %% [markdown]
# For line 30 and 31, .info shows the metadata of each city's dataframe.

# %%
#the Info method can be used to check the data types, size of data frame and the number of missing values

df_seattle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1658 entries, 0 to 1657
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  1658 non-null   object
#  1   NAME     1658 non-null   object
#  2   DATE     1658 non-null   object
#  3   DAPR     23 non-null     float64
#  4   MDPR     23 non-null     float64
#  5   PRCP     1636 non-null   float64
#  6   SNOW     353 non-null    float64
#  7   SNWD     66 non-null     float64
#  8   WESD     15 non-null     float64
#  9   WESF     28 non-null     float64
# dtypes: float64(7), object(3)
# memory usage: 129.7+ KB

# %% [markdown]
# output: outputs the metadata info

# %%
df_michigan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1770 entries, 0 to 1769
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STATION          1770 non-null   object
#  1   NAME             1770 non-null   object
#  2   LATITUDE         1770 non-null   float64
#  3   LONGITUDE        1770 non-null   float64
#  4   ELEVATION        1770 non-null   float64
#  5   DATE             1770 non-null   object
#  6   DAPR             15 non-null     float64
#  7   DAPR_ATTRIBUTES  15 non-null     object
#  8   MDPR             15 non-null     float64
#  9   MDPR_ATTRIBUTES  15 non-null     object
#  10  PRCP             1755 non-null   float64
#  11  PRCP_ATTRIBUTES  1755 non-null   object
#  12  SNOW             1733 non-null   float64
#  13  SNOW_ATTRIBUTES  1733 non-null   object
#  14  SNWD             1257 non-null   float64
#  15  SNWD_ATTRIBUTES  1257 non-null   object
# ...

# %% [markdown]
# For line 32 & 33, df_seattle.shape & df_seattle.shape returns dimension of DataFrame

# %%
#To compare data frame sizes we can use the shape attribute. This will tell us the number of rows and columns
print(df_seattle.shape)
# Out:
# (1658, 10)

# %% [markdown]
# Output: provides the dimension as rows and columns. same as below which provides dimension for michigan dataframe.

# %%
print(df_michigan.shape)
# Out:
# (1770, 20)

# %% [markdown]
# Selects and displays the records in the column 'STATION'

# %%
#To access one particular column in our data set. 

df_michigan['STATION']
# Out:
# 0       US1MIMR0016
# 1       US1MIMR0016
# 2       US1MIMR0016
# 3       US1MIMR0016
# 4       US1MIMR0016
#            ...
# 1765    US1MIMR0016
# 1766    US1MIMR0016
# 1767    US1MIMR0016
# 1768    US1MIMR0016
# 1769    US1MIMR0016
# Name: STATION, Length: 1770, dtype: object

# %% [markdown]
# Output: prints the first 5 records for the STATION column and also last 5 records

# %% [markdown]
# df_michigan['STATION'] selects the column STATION and outputs the name of the unique station.

# %%
#To obtain the number of unique stations
df_michigan['STATION'].unique()
# Out:
# array(['US1MIMR0016'], dtype=object)

# %% [markdown]
# Output shows the name of the unique station

# %%
#To determine the number of unique elements
df_michigan['STATION'].nunique()
# Out:
# 1

# %% [markdown]
# df_seattle['STATION'] selects the records in column labelled station and outputs the number of unique STATIONS.

# %%
df_seattle['STATION'].nunique()
# Out:
# 1

# %% [markdown]
# Output: there's only one station where our data is obtained from hence it returns 1 as the only unique station in our dataset.

# %%
#To examine the date column
df_seattle['DATE']
# Out:
# 0         1/1/18
# 1         1/2/18
# 2         1/3/18
# 3         1/4/18
# 4         1/5/18
#           ...
# 1653    12/27/22
# 1654    12/28/22
# 1655    12/29/22
# 1656    12/30/22
# 1657    12/31/22
# Name: DATE, Length: 1658, dtype: object

# %%
#To examine the date column
df_michigan['DATE']
# Out:
# 0       2018-01-01
# 1       2018-01-02
# 2       2018-01-03
# 3       2018-01-04
# 4       2018-01-05
#            ...
# 1765    2022-12-27
# 1766    2022-12-28
# 1767    2022-12-29
# 1768    2022-12-30
# 1769    2022-12-31
# Name: DATE, Length: 1770, dtype: object

# %%
#NOTE: Obtaining the earliest and latest date could lead to incorrect answers as our dates are strings and not in correct date format
df_seattle['DATE'].max()
# Out:
# '9/9/22'

# %%
df_seattle['DATE'].min()
# Out:
# '1/1/18'

# %%
df_seattle['DATE'].tail()
# Out:
# 1653    12/27/22
# 1654    12/28/22
# 1655    12/29/22
# 1656    12/30/22
# 1657    12/31/22
# Name: DATE, dtype: object

# %% [markdown]
# max() and min() are explained below including the possible outputs.

# %%
df_michigan['DATE'].max()
# Out:
# '2022-12-31'

# %%
df_michigan['DATE'].min()
# Out:
# '2018-01-01'

# %% [markdown]
# For Line 46 & 47, convert DATE from the string format to the accurate(datetime) format using panda's to_datetime function and provide selected DATE record as parameter to the function.

# %%
# converting DATE to datetime for Seattle rain data
#convert the existing string format of date to the correct date and time format

df_seattle['DATE'] = pd.to_datetime(df_seattle['DATE'])

#the result of the conversion is that the entire date column will contain records in the correct date and time format
# Out:
# /var/folders/fl/1v09j2_57fg6drj48nv618w00000gn/T/ipykernel_64710/3056656500.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_seattle['DATE'] = pd.to_datetime(df_seattle['DATE'])

# %%
# converting DATE to datetime for michigan rain data
#convert the existing string format of date to the correct date and time format
df_michigan['DATE'] = pd.to_datetime(df_michigan['DATE'])

#the result of the conversion is that the entire date column will contain records in the correct date and time format

# %% [markdown]
# For line 46 & 47, the selected column is replaced with dates that have been corrected to the accurate datetime format rather than string. Nothing is printed but new changes are assigned to our selected columns.

# %% [markdown]
# To view summary of DATE column

# %%
#To view our DATE column
df_seattle['DATE']

#outputs column with our dates
# Out:
# 0      2018-01-01
# 1      2018-01-02
# 2      2018-01-03
# 3      2018-01-04
# 4      2018-01-05
#           ...
# 1653   2022-12-27
# 1654   2022-12-28
# 1655   2022-12-29
# 1656   2022-12-30
# 1657   2022-12-31
# Name: DATE, Length: 1658, dtype: datetime64[ns]

# %% [markdown]
# To view a summary of our date column

# %%
#To view our DATE column for Michigan
df_michigan['DATE']

#outputs column with our dates
# Out:
# 0      2018-01-01
# 1      2018-01-02
# 2      2018-01-03
# 3      2018-01-04
# 4      2018-01-05
#           ...
# 1765   2022-12-27
# 1766   2022-12-28
# 1767   2022-12-29
# 1768   2022-12-30
# 1769   2022-12-31
# Name: DATE, Length: 1770, dtype: datetime64[ns]

# %% [markdown]
# Output shows out date columns with the first 5 earliest dates and the latest 5 dates.

# %%
# To determine the latest date
df_seattle['DATE'].min()
#Result: outputs date and timestamp
# Out:
# Timestamp('2018-01-01 00:00:00')

# %% [markdown]
# df_seattle['DATE'] selects the column with label DATE and returns latest date

# %%
#to determine the latest date
df_seattle['DATE'].max()
# Out:
# Timestamp('2022-12-31 00:00:00')

# %% [markdown]
# Perform max and min operations to return the earliest and latest date in our series

# %%
#to perform multiple aggregations - min and max
df_seattle['DATE'].agg(['min', 'max'])
#outputs the earliest and latest dates
# Out:
# min   2018-01-01
# max   2022-12-31
# Name: DATE, dtype: datetime64[ns]

# %% [markdown]
# df_michigan['DATE'] selects the DATE column from the DataFrame df_michigan.
# .agg(['min','max']) allows us to apply one or more functions to a series or Dataframe
# min returns the earliest date in the series
# max returns the latest date in the series

# %%
#to perform multiple aggregations - min and max
df_michigan['DATE'].agg(['min', 'max'])
#outputs the earliest and latest dates
# Out:
# min   2018-01-01
# max   2022-12-31
# Name: DATE, dtype: datetime64[ns]

# %% [markdown]
# output: shows the earliest and the latest date in our dataset.

# %% [markdown]
# Using Seaborn lineplot to plot the precipitation for Seattle data set for the period concerned.
# plt.figure(figsize=(20,5)) creates a figure for plot that has a width of 20 inches and height of 5 inches.
# sns.lineplot(data=df_michigan, x='DATE', y='PRCP') uses Seaborn's lineplot to plot a line chart. The x axis will show the date and y axis will show PRCP. The labels of the x and y axis are provided fint sizes.
# plt.tick_params(labelsize=15): this will adjust the size of the tick labels on both axis to 15 points.
# plt.show will display the lineplot.

# %%
plt.figure(figsize = (20,5))
sns.lineplot(data=df_seattle, x='DATE', y='PRCP')

plt.xlabel('Date', fontsize=18)
plt.ylabel('Precipitation (inches)', fontsize=18)

plt.tick_params(labelsize=15)
plt.show()

#outputs a graph taking account of inputs as provided

# %% [markdown]
# Output: the line plot is dispalyed. we see that most days seem to be repressented.However we can see in 2018, that there is a lie that is slanting connecting one day plot to another day. The day in those days under the curve are likely missing. Must come up with a process to determine those dates.

# %% [markdown]
# Using Seaborn lineplot to plot the precipitation for Michigan data set for the period concerned.
# plt.figure(figsize=(20,5)) creates a figure for plot that has a width of 20 inches and height of 5 inches.
# sns.lineplot(data=df_michigan, x='DATE', y='PRCP') uses Seaborn's lineplot to plot a line chart. The x axis will show the date and y axis will show PRCP. The labels of the x and y axis are provided fint sizes.
# plt.tick_params(labelsize=15): this will adjust the size of the tick labels on both axis to 15 points.
# plt.show will display the lineplot.

# %%
plt.figure(figsize = (20,5))
sns.lineplot(data=df_michigan, x='DATE', y='PRCP')

plt.xlabel('Date', fontsize=18)
plt.ylabel('Precipitation (inches)', fontsize=18)

plt.tick_params(labelsize=15)
plt.show()

#outputs a graph taking account of inputs as provided

# %% [markdown]
# outputs a line plot that shows our data from 2018 - 2022 end. Data does not include any breaks

# %% [markdown]
# provides summary on metadata of michigan dataframe/dataset

# %%
#provides summary on metadata of dataset
df_michigan.info()

#provides the summary for michigan dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1770 entries, 0 to 1769
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STATION          1770 non-null   object
#  1   NAME             1770 non-null   object
#  2   LATITUDE         1770 non-null   float64
#  3   LONGITUDE        1770 non-null   float64
#  4   ELEVATION        1770 non-null   float64
#  5   DATE             1770 non-null   datetime64[ns]
#  6   DAPR             15 non-null     float64
#  7   DAPR_ATTRIBUTES  15 non-null     object
#  8   MDPR             15 non-null     float64
#  9   MDPR_ATTRIBUTES  15 non-null     object
#  10  PRCP             1755 non-null   float64
#  11  PRCP_ATTRIBUTES  1755 non-null   object
#  12  SNOW             1733 non-null   float64
#  13  SNOW_ATTRIBUTES  1733 non-null   object
#  14  SNWD             1257 non-null   float64
#  15  SNWD_ATTRIBUTES  1257 non-null   object
# ...

# %% [markdown]
# outputs metadata info.
#
# Provides summary on metadata of Seattle dataset

# %%
df_seattle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1658 entries, 0 to 1657
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  1658 non-null   object
#  1   NAME     1658 non-null   object
#  2   DATE     1658 non-null   datetime64[ns]
#  3   DAPR     23 non-null     float64
#  4   MDPR     23 non-null     float64
#  5   PRCP     1636 non-null   float64
#  6   SNOW     353 non-null    float64
#  7   SNWD     66 non-null     float64
#  8   WESD     15 non-null     float64
#  9   WESF     28 non-null     float64
# dtypes: datetime64[ns](1), float64(7), object(2)
# memory usage: 129.7+ KB

# %% [markdown]
# Output: table containing info on our metadata is outputted.
#
#
#
# From both data set, keep only the DATE and PRCP columns
# Merge the two DataFrames together on the DATE column
# Use an outer join so that all dates from both datasets are kept
# If a date exists in Michigan but not Seattle, Seattle's PRCP will be NaN
# If a date exists in Seattle but not Michigan, Michigan's PRCP will be NaN
# The final result is stored in df

# %%
df = df_michigan[['DATE','PRCP']].merge(df_seattle[['DATE', 'PRCP']], on='DATE', how='outer')

# %% [markdown]
# Output: performs the merge operation and assigns to df

# %%
df.head()
# Out:
#         DATE  PRCP_x  PRCP_y
# 0 2018-01-01    0.00    0.00
# 1 2018-01-02    0.00    0.00
# 2 2018-01-03    0.00    0.00
# 3 2018-01-04    0.02    0.00
# 4 2018-01-05    0.00    0.25

# %% [markdown]
# Panda's function 'melt' is used to reshape a dataframe from wide to tidy format. Our two columns containing precipitation data are collapsed into one.

# %%
df = pd.melt(df, id_vars='DATE', var_name='city', value_name='precipitation')

# %% [markdown]
# The result after applying the melt function is reassigned to df.
#
# To view our records in the table we use .head()

# %%
df.head()
# Out:
#         DATE    city  precipitation
# 0 2018-01-01  PRCP_x           0.00
# 1 2018-01-02  PRCP_x           0.00
# 2 2018-01-03  PRCP_x           0.00
# 3 2018-01-04  PRCP_x           0.02
# 4 2018-01-05  PRCP_x           0.00

# %% [markdown]
# Renaming the names of our cities in order to meet best practices and convey better info. Michigan is indicated as DTW and Seattle as SEA

# %% [markdown]
# .loc is used to selected rows and columns by label.
# df.loc[df['city'] == 'PRCP_x', 'city'] implies you select all rows where city is 'PRCP_x' and select the city colums  in those rows
# the selected data is then changed to 'DTW' using ='DTW'.

# %%
df.loc[df['city'] == 'PRCP_x', 'city'] = 'DTW'

# %% [markdown]
# Output: all places where PRCP_x appears is replaced with 'DTW' in the city column
#
# .head() is used to output/display the first 5 records of our table

# %%
#outputs first 5 records of table
df.head()
# Out:
#         DATE city  precipitation
# 0 2018-01-01  DTW           0.00
# 1 2018-01-02  DTW           0.00
# 2 2018-01-03  DTW           0.00
# 3 2018-01-04  DTW           0.02
# 4 2018-01-05  DTW           0.00

# %% [markdown]
# the code renames any record under the city column with PRCP_y name to 'SEA'

# %%
df.loc[df['city'] == 'PRCP_y', 'city'] = 'SEA'

# %% [markdown]
# there is not output, the code simply alters the name as indicated above

# %% [markdown]
# .tail() is used to view the last 5 records in our table

# %%
df.tail()
# Out:
#            DATE city  precipitation
# 3641 2022-12-27  SEA           0.78
# 3642 2022-12-28  SEA           0.40
# 3643 2022-12-29  SEA           0.03
# 3644 2022-12-30  SEA           0.62
# 3645 2022-12-31  SEA           0.17

# %% [markdown]
# output shows the last 5 records

# %% [markdown]
# df.rename allows us to rename a specific column like DATE column to lower case

# %%
#Rename the column date to lowercase
df = df.rename(columns={'DATE': 'date'})
#Date is renamed to lower case date and change is assigned to df

# %% [markdown]
# Output: the table created is reassigned to df

# %% [markdown]
# To view our table showing 5 records including label

# %%
df.head()
# Out:
#         date city  precipitation
# 0 2018-01-01  DTW           0.00
# 1 2018-01-02  DTW           0.00
# 2 2018-01-03  DTW           0.00
# 3 2018-01-04  DTW           0.02
# 4 2018-01-05  DTW           0.00

# %% [markdown]
# Output: when .head() is used, output shows table with first 5 records

# %% [markdown]
# Displays summary information about the data frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3646 entries, 0 to 3645
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           3646 non-null   datetime64[ns]
#  1   city           3646 non-null   object
#  2   precipitation  3391 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 85.6+ KB

# %% [markdown]
# Output: shows summary data of the data set. shows the number of non-null values for date, city and precipitation. We see the precipitation shows lower number hence some data could be missing.

# %% [markdown]
# Displays the number of not null values for each column

# %%
df.notna().sum()
# Out:
# date             3646
# city             3646
# precipitation    3391
# dtype: int64

# %% [markdown]
# Output: shows summary data of the data set. shows the number of non-null values for date, city and precipitation. We see the precipitation shows lower number hence some data could be missing.

# %% [markdown]
# We can also find the exact number of null values using .isna() which returns each null values, and we can do a summation to find their total number by chaining .isna() with sum().

# %%
df.isna().sum()
# Out:
# date               0
# city               0
# precipitation    255
# dtype: int64

# %% [markdown]
# Output: there are no null values found for date, city hence why they show 0. Precipitation has about 255 null values.

# %% [markdown]
# To find the specific number of null values related to Seattle and those related to Michigan. We write the following:

# %%
df.loc[df['city'] == 'SEA', 'precipitation'].isna().sum()
# Out:
# np.int64(187)

# %% [markdown]
# Output: this indicated a numpy 64 bits integer object. 187 shows the number of null values.

# %%
df.loc[df['city'] == 'DTW', 'precipitation'].isna().sum()
# Out:
# np.int64(68)

# %% [markdown]
# Output: this indicates a numpy 64 bitws integer while 68 shows there are 68 null reocrd for our precipitation column.

# %% [markdown]
# To impute the missing values for both data sets, there are multiple approaches we can follow. I choose to use the mean value across all of the values on that day.

# %% [markdown]
# In order to perform compution, need to define column that labels each day of the year 1,2,.....365.

# %%
df['day_of_year'] = pd.DatetimeIndex(df['date']).day_of_year

# %% [markdown]
# Display top 10 records in our data

# %%
df.head(10)
# Out:
#         date city  precipitation  day_of_year
# 0 2018-01-01  DTW           0.00            1
# 1 2018-01-02  DTW           0.00            2
# 2 2018-01-03  DTW           0.00            3
# 3 2018-01-04  DTW           0.02            4
# 4 2018-01-05  DTW           0.00            5
# 5 2018-01-06  DTW           0.00            6
# 6 2018-01-07  DTW           0.00            7
# 7 2018-01-08  DTW           0.15            8
# 8 2018-01-09  DTW           0.00            9
# 9 2018-01-10  DTW           0.00           10

# %% [markdown]
# Output: data indicates first 10 day (for first 10 days) in our record pertaining to DTW.

# %% [markdown]
# To compute the mean precipitation for each day in Seattle averaged across the years.

# %% [markdown]
# df.loc[df['city'] == 'SEA', ['precipitation', 'day_of_year']] filters the data frame to keep only rows where city == 'SEA' & only keeps precipitation and day_ofOyear columns.
# .groupby('day_of_year') usually groups the filtered DataFrame by day_of_year.
# .mean() : For each group, it computes the average precipitation across of years of the dataset.

# %%
#mean_day_precipitation = df.loc[df['city'] == 'SEA', ['precipitation', 'day_of_year']].groupby('day_of_year').mean()
mean_day_precipitation_sea = df.loc[df['city'] == 'SEA', ['precipitation', 'day_of_year']].groupby('day_of_year').mean()
mean_day_precipitation_dtw = df.loc[df['city'] == 'DTW', ['precipitation', 'day_of_year']].groupby('day_of_year').mean()

# %% [markdown]
# To create a line plot showing the mean distribution

# %%
#plt.figure(figsize=(20,5))

#sns.lineplot(data=mean_day_precipitation, x='day_of_year', y='precipitation')

#plt.xlabel('Day of the year', fontsize=18)
#plt.ylabel('Mean precipitation (inches)', fontsize=18)

#plt.tick_params(labelsize=15)

#plt.show()

# %% [markdown]
# To create a line plot representing the mean of our data set for seattle data

# %%
plt.figure(figsize=(20,5))
sns.lineplot(data=mean_day_precipitation_sea, x='day_of_year', y='precipitation')

plt.xlabel('Day of the year', fontsize=18)
plt.ylabel('Mean precipitation (inches)', fontsize=18)

plt.tick_params(labelsize=15)

plt.show()

# %% [markdown]
# To create a line plot representing the mean of our data set for michigan data

# %%
plt.figure(figsize=(20,5))
sns.lineplot(data=mean_day_precipitation_dtw, x='day_of_year', y='precipitation')

plt.xlabel('Day of the year', fontsize=18)
plt.ylabel('Mean precipitation (inches)', fontsize=18)

plt.tick_params(labelsize=15)

plt.show()

# %% [markdown]
# Output: shows the lineplot for the mean of the selected date of the year. W

# %% [markdown]
# Now, need to replace the places where we have NaN or null with our determined mean.

# %%
df.head()
# Out:
#         date city  precipitation  day_of_year
# 0 2018-01-01  DTW           0.00            1
# 1 2018-01-02  DTW           0.00            2
# 2 2018-01-03  DTW           0.00            3
# 3 2018-01-04  DTW           0.02            4
# 4 2018-01-05  DTW           0.00            5

# %% [markdown]
# To determine where we have Nan we can use boolean logic to determine where isna() == True.

# %%
df['precipitation'].isna() == True
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3641    False
# 3642    False
# 3643    False
# 3644    False
# 3645    False
# Name: precipitation, Length: 3646, dtype: bool

# %% [markdown]
# To obtain the index of each row where precipitation is missing

# %%
#indices = np.where(df['precipitation'].isna() == True)[0]

indices_SEA = np.where((df['precipitation'].isna()) & (df['city'] == 'SEA'))[0]

indices_DTW = np.where((df['precipitation'].isna()) & (df['city'] == 'DTW'))[0]

# %% [markdown]
# Replace missing value with mean on that day using for loop:

# %%
for index in indices_SEA:
    df.loc[index, 'precipitation'] = mean_day_precipitation_sea.loc[df.loc[index, 'day_of_year']].values[0]

for index in indices_DTW:
    df.loc[index, 'precipitation'] = mean_day_precipitation_dtw.loc[df.loc[index, 'day_of_year']].values[0]

# %%
Output: for loop iterates over the precipitation and depending on whether it is is Seattle or Michigan the accurate mean is used to replace the Nan value.

# %% [markdown]
# To check if we are still missing values from the data set we check with isna().sum()

# %%
df.isna().sum()
# Out:
# date             0
# city             0
# precipitation    0
# day_of_year      0
# dtype: int64

# %% [markdown]
# Output: indicates that all NaN values have been replaced with the mean value respectively.

# %% [markdown]
# To export clean .csv file

# %%
df.to_csv('clean_seattle_michigan_weather.csv', encoding='utf-8-sig', index=False)
